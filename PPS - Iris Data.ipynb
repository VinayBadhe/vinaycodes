# %%
# !pip install ppscore

# %%
import pandas as pd
import ppscore as pps

# %%
iris=pd.read_csv('iris (1).csv')
iris
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
pps.score(iris,'Sepal.Length','Petal.Length' )
# Out:
# {'x': 'Sepal.Length',
#  'y': 'Petal.Length',
#  'ppscore': 0.550422595049248,
#  'case': 'regression',
#  'is_valid_score': True,
#  'metric': 'mean absolute error',
#  'baseline_score': 1.4886666666666668,
#  'model_score': 0.6692708968366863,
#  'model': DecisionTreeRegressor()}

# %%
pps.matrix(iris)
# Out:
#                x             y   ppscore            case  is_valid_score  \
# 0     Unnamed: 0    Unnamed: 0  1.000000  predict_itself            True
# 1     Unnamed: 0  Sepal.Length  0.202091      regression            True
# 2     Unnamed: 0   Sepal.Width  0.000000      regression            True
# 3     Unnamed: 0  Petal.Length  0.686620      regression            True
# 4     Unnamed: 0   Petal.Width  0.644777      regression            True
# 5     Unnamed: 0       Species  0.979345  classification            True
# 6   Sepal.Length    Unnamed: 0  0.237121      regression            True
# 7   Sepal.Length  Sepal.Length  1.000000  predict_itself            True
# 8   Sepal.Length   Sepal.Width  0.000000      regression            True
# 9   Sepal.Length  Petal.Length  0.550423      regression            True
# 10  Sepal.Length   Petal.Width  0.431739      regression            True
# 11  Sepal.Length       Species  0.471649  classification            True
# ...
