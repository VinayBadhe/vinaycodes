# %%
import pandas

# %%
v=pandas.read_csv('C:/Users/Administrator/Downloads/IPL IMB381IPL2013.csv')
v
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
type(v)
# Out:
# pandas.core.frame.DataFrame

# %%
v.shape
# Out:
# (130, 26)

# %%
v.columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
v.dtypes
# Out:
# Sl.NO.             int64
# PLAYER NAME       object
# AGE                int64
# COUNTRY           object
# TEAM              object
# PLAYING ROLE      object
# T-RUNS             int64
# T-WKTS             int64
# ODI-RUNS-S         int64
# ODI-SR-B         float64
# ODI-WKTS           int64
# ODI-SR-BL        float64
# CAPTAINCY EXP      int64
# RUNS-S             int64
# HS                 int64
# AVE              float64
# SR-B             float64
# SIXERS             int64
# RUNS-C             int64
# WKTS               int64
# AVE-BL           float64
# ECON             float64
# SR-BL            float64
# AUCTION YEAR       int64
# BASE PRICE         int64
# SOLD PRICE         int64
# dtype: object

# %%
v.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
v.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
v.tail(8)
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 122     123     Warne, SK    3     AUS     RR       Bowler    3154     708
# 123     124    Warner, DA    1     AUS     DD      Batsman     483       2
# 124     125     White, CL    2     AUS   RCB+      Batsman     146       5
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 122        1018     72.04  ...   92.52       6    1447    57   25.39   7.27
# 123         876     85.79  ...  135.76      44       0     0    0.00   0.00
# ...

# %%
v[['PLAYER NAME']]
# Out:
#       PLAYER NAME
# 0     Abdulla, YA
# 1    Abdur Razzak
# 2     Agarkar, AB
# 3       Ashwin, R
# 4    Badrinath, S
# ..            ...
# 125     Yadav, AS
# 126   Younis Khan
# 127  Yuvraj Singh
# 128   Zaheer Khan
# 129    Zoysa, DNT
#
# [130 rows x 1 columns]

# %%
v.PLAYER NAME #YOU CANNOT USE DOT NOTATION FOR SUBSETTING COLUMNS IF COLUMN NAME HAS SPECIAL CHARECTOR
# Out:
#   File "C:\Users\Administrator\AppData\Local\Temp\ipykernel_6660\3610615507.py", line 1
#     v.PLAYER NAME #YOU CANNOT USE DOT NOTATION FOR SUBSETTING COLUMNS IF COLUMN NAME HAS SPECIAL CHARECTOR
#              ^
# SyntaxError: invalid syntax

# %%
v.TEAM
# Out:
# 0       KXIP
# 1        RCB
# 2        KKR
# 3        CSK
# 4        CSK
#        ...
# 125       DC
# 126       RR
# 127    KXIP+
# 128      MI+
# 129       DC
# Name: TEAM, Length: 130, dtype: object

# %%
type(v.head(1)) #subsetting 1st row, but it is returned as dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
type(v.loc[0]) #subsetting 1st row, but it is returned as series
# Out:
# pandas.core.series.Series

# %%
v.loc[[1,9,56]]
# Out:
#     Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 1        2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 9       10   Boucher, MV    2      SA  RCB+    W. Keeper    5515       1
# 56      57  Maharoof, MF    2      SL    DD   Allrounder     556      25
#
#     ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 1          657     71.41  ...    0.00       0      29     0    0.00  14.50
# 9         4686     84.76  ...  127.51      13       0     0    0.00   0.00
# 56        1042     84.44  ...  143.90       9     520    27   19.26   7.43
#
#     SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 1    0.00          2008       50000       50000
# 9    0.00          2008      200000      450000
# 56  15.56          2008      150000      225000
#
# [3 rows x 26 columns]

# %%
v.tail(1)
# Out:
#      Sl.NO. PLAYER NAME  AGE COUNTRY TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 129     130  Zoysa, DNT    2      SL   DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 129         343     95.81  ...  122.22       0      99     2    49.5   9.0
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 129   33.0          2008      100000      110000
#
# [1 rows x 26 columns]

# %%
v.iloc[-1]
# Out:
# Sl.NO.                  130
# PLAYER NAME      Zoysa, DNT
# AGE                       2
# COUNTRY                  SL
# TEAM                     DC
# PLAYING ROLE         Bowler
# T-RUNS                  288
# T-WKTS                   64
# ODI-RUNS-S              343
# ODI-SR-B              95.81
# ODI-WKTS                108
# ODI-SR-BL              39.4
# CAPTAINCY EXP             0
# RUNS-S                   11
# HS                       10
# AVE                    11.0
# SR-B                 122.22
# SIXERS                    0
# RUNS-C                   99
# WKTS                      2
# AVE-BL                 49.5
# ECON                    9.0
# SR-BL                  33.0
# AUCTION YEAR           2008
# BASE PRICE           100000
# SOLD PRICE           110000
# Name: 129, dtype: object

# %%
v.loc[:,['PLAYER NAME','COUNTRY','TEAM','SOLD PRICE']]
# Out:
#       PLAYER NAME COUNTRY   TEAM  SOLD PRICE
# 0     Abdulla, YA      SA   KXIP       50000
# 1    Abdur Razzak     BAN    RCB       50000
# 2     Agarkar, AB     IND    KKR      350000
# 3       Ashwin, R     IND    CSK      850000
# 4    Badrinath, S     IND    CSK      800000
# ..            ...     ...    ...         ...
# 125     Yadav, AS     IND     DC      750000
# 126   Younis Khan     PAK     RR      225000
# 127  Yuvraj Singh     IND  KXIP+     1800000
# 128   Zaheer Khan     IND    MI+      450000
# 129    Zoysa, DNT      SL     DC      110000
#
# [130 rows x 4 columns]

# %%
v.iloc[5:50:3,6:24:2]
# Out:
#     T-RUNS  ODI-RUNS-S  ODI-WKTS  CAPTAINCY EXP   HS    SR-B  RUNS-C  AVE-BL  \
# 5        0         172         0              1   48   95.45       0    0.00
# 8       83         609        72              1   67  114.73     610   32.11
# 11    9918        8778        14              1   16   80.64       0    0.00
# 14       0          69         0              0   95  122.32      66   16.50
# 17       0          18         5              0    2   33.33     926   25.72
# 20     380          73        60              0    3   80.00     154   30.80
# 23    3845        3394       169              1   24  116.98     105   52.50
# 26    6373        8087       156              1  128  161.79     606   46.62
# 29       0           0         2              0   15  117.39     999   33.30
# 32    8625        6133         0              0   93  137.52       0    0.00
# 35     503         575         1              0   73  121.50     300   17.65
# ...

# %%
v.groupby('COUNTRY')['SOLD PRICE'].mean()
# Out:
# COUNTRY
# AUS    4.340909e+05
# BAN    5.000000e+04
# ENG    1.066667e+06
# IND    6.523396e+05
# NZ     5.264286e+05
# PAK    3.305556e+05
# SA     4.275000e+05
# SL     4.237500e+05
# WI     2.791667e+05
# ZIM    1.250000e+05
# Name: SOLD PRICE, dtype: float64

# %%
d=v.groupby(['COUNTRY','PLAYING ROLE'])[['SOLD PRICE','SIXERS']].mean()
d
# Out:
#                         SOLD PRICE     SIXERS
# COUNTRY PLAYING ROLE
# AUS     Allrounder    4.125000e+05  17.500000
#         Batsman       3.333333e+05  21.222222
#         Bowler        5.625000e+05   2.666667
#         W. Keeper     7.000000e+05  86.000000
# BAN     Bowler        5.000000e+04   0.000000
# ENG     Allrounder    8.250000e+05   1.500000
#         Batsman       1.550000e+06  30.000000
# IND     Allrounder    5.607143e+05  26.142857
#         Batsman       9.388889e+05  40.111111
#         Bowler        4.795217e+05   2.695652
#         W. Keeper     5.440000e+05  34.200000
# NZ      Allrounder    4.087500e+05   7.250000
#         Batsman       6.750000e+05  24.000000
#         W. Keeper     7.000000e+05  48.000000
# PAK     Allrounder    5.875000e+05   3.000000
#         Batsman       1.625000e+05   3.000000
#         Bowler        3.312500e+05   1.500000
#         W. Keeper     1.500000e+05   8.000000
# SA      Allrounder    5.464286e+05  14.571429
# ...

# %%
d.reset_index()
# Out:
#    COUNTRY PLAYING ROLE    SOLD PRICE     SIXERS
# 0      AUS   Allrounder  4.125000e+05  17.500000
# 1      AUS      Batsman  3.333333e+05  21.222222
# 2      AUS       Bowler  5.625000e+05   2.666667
# 3      AUS    W. Keeper  7.000000e+05  86.000000
# 4      BAN       Bowler  5.000000e+04   0.000000
# 5      ENG   Allrounder  8.250000e+05   1.500000
# 6      ENG      Batsman  1.550000e+06  30.000000
# 7      IND   Allrounder  5.607143e+05  26.142857
# 8      IND      Batsman  9.388889e+05  40.111111
# 9      IND       Bowler  4.795217e+05   2.695652
# 10     IND    W. Keeper  5.440000e+05  34.200000
# 11      NZ   Allrounder  4.087500e+05   7.250000
# 12      NZ      Batsman  6.750000e+05  24.000000
# 13      NZ    W. Keeper  7.000000e+05  48.000000
# 14     PAK   Allrounder  5.875000e+05   3.000000
# 15     PAK      Batsman  1.625000e+05   3.000000
# 16     PAK       Bowler  3.312500e+05   1.500000
# 17     PAK    W. Keeper  1.500000e+05   8.000000
# ...

# %%
v.groupby('COUNTRY')['PLAYER NAME'].nunique()
# Out:
# COUNTRY
# AUS    22
# BAN     1
# ENG     3
# IND    53
# NZ      7
# PAK     9
# SA     16
# SL     12
# WI      6
# ZIM     1
# Name: PLAYER NAME, dtype: int64

# %%
v.groupby('COUNTRY')['PLAYER NAME'].value_counts()
# Out:
# COUNTRY  PLAYER NAME
# AUS      Bailey, GJ       1
#          Bollinger, DE    1
#          Gilchrist, AC    1
#          Harris, RJ       1
#          Hayden, ML       1
#                          ..
# WI       Edwards, FH      1
#          Gayle, CH        1
#          Sarwan, RR       1
#          Smith, DR        1
# ZIM      Taibu, T         1
# Name: PLAYER NAME, Length: 130, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
v.groupby('AUCTION YEAR')['SOLD PRICE'].mean().plot()
# Out:
# <AxesSubplot:xlabel='AUCTION YEAR'>
