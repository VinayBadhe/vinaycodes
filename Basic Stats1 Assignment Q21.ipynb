# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
cars=pd.read_csv('Cars (1).csv')
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
import matplotlib.pyplot as plt

# %%
plt.his;

# %%
import statsmodels.api as sm

# %%
sm.qqplot(cars['MPG'], line='45');

# %%
cars['MPG'].plot(kind='box't);

# %% [markdown]
# ### Thus, MPG follows normal distribution

# %%
wc_at=pd.read_csv('WC_AT.csv')
wc_at.head()
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
plt.hist(wc_at['Waist']);

# %%
sm.qqplot(wc_at['Waist'], line='45');

# %%
wc_at['Waist'].plot(kind='box');

# %% [markdown]
# ### Thus, Waist follows normal distribution

# %%
plt.hist(wc_at['AT']);

# %%
sm.qqplot(wc_at['AT'], line='45');

# %%
wc_at['AT'].plot(kind='box');

# %% [markdown]
# ### Thus, AT follows normal distribution
